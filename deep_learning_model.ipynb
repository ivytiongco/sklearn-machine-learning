# %%
# Update sklearn to prevent version mismatches
# !conda install scikit-learn
# !conda update scikit-learn
# !conda install joblib 
# !conda update joblib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Remove Space for `FALSE POSITIVE` category
mask = df["koi_disposition"] == "FALSE POSITIVE"
df.loc[mask, "koi_disposition"] = "False_Positive"
df["koi_disposition"]
# Out:
# 0            CONFIRMED
# 1       False_Positive
# 2       False_Positive
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    False_Positive
# 6987    False_Positive
# 6988         CANDIDATE
# 6989    False_Positive
# 6990    False_Positive
# Name: koi_disposition, Length: 6991, dtype: object

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
y = df["koi_disposition"]
X = df.drop(columns=["koi_disposition"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4002              0              0              1              0   99.673478
# 4246              0              1              0              0    0.592244
# 548               0              1              1              0    9.991625
# 3953              0              1              0              0  178.412990
# 2362              0              0              0              0   45.294223
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4002     3.463000e-04    -3.463000e-04   219.334830          0.002300
# 4246     9.000000e-08    -9.000000e-08   131.654831          0.000124
# 548      5.360000e-06    -5.360000e-06   137.447816          0.000445
# 3953     3.100000e-05    -3.100000e-05   218.225235          0.000127
# 2362     5.600000e-05    -5.600000e-05   138.678725          0.000987
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 4002         -0.002300  ...            -148      4.777           0.040
# 4246         -0.000124  ...            -146      4.664           0.056
# 548          -0.000445  ...            -176      4.338           0.153
# 3953         -0.000127  ...            -134      4.346           0.084
# 2362         -0.000987  ...             -68      4.347           0.030
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 4002          -0.027     0.492          0.026         -0.027  293.05801
# 4246          -0.032     0.591          0.045         -0.045  290.28094
# 548           -0.187     1.096          0.309         -0.206  301.04239
# 3953          -0.126     1.148          0.202         -0.124  288.32785
# 2362          -0.030     1.044          0.057         -0.042  285.67938
#
#             dec  koi_kepmag
# 4002  45.248821      15.801
# 4246  45.464260      15.653
# 548   45.022888      14.039
# 3953  38.627621      13.944
# 2362  50.241299      10.961
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using LabelEncoder and MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
y_train_categorical.shape
# Out:
# (5243, 3)

# %% [markdown]
# # Train the Model

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               4100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 14,503
# Trainable params: 14,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
# set early stopping as callback
callbacks = [EarlyStopping(monitor='val_loss', patience=2)]
model.fit(
    X_train_scaled,
    y_train_categorical,
    callbacks=callbacks,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.5401 - accuracy: 0.7328
# Epoch 2/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3719 - accuracy: 0.7999
# Epoch 3/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3515 - accuracy: 0.8240
# Epoch 4/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3424 - accuracy: 0.8295
# Epoch 5/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3369 - accuracy: 0.8316
# Epoch 6/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3313 - accuracy: 0.8388
# Epoch 7/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3254 - accuracy: 0.8478
# Epoch 8/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3190 - accuracy: 0.8503
# Epoch 9/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3151 - accuracy: 0.8495
# Epoch 10/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3128 - accuracy: 0.8550
# Epoch 11/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3057 - accuracy: 0.8552
# Epoch 12/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3022 - accuracy: 0.8621
# Epoch 13/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.3076 - accuracy: 0.8556
# Epoch 14/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2998 - accuracy: 0.8629
# Epoch 15/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2901 - accuracy: 0.8707
# Epoch 16/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2934 - accuracy: 0.8667
# Epoch 17/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2897 - accuracy: 0.8701
# Epoch 18/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2881 - accuracy: 0.8714
# Epoch 19/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2875 - accuracy: 0.8734
# Epoch 20/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2844 - accuracy: 0.8743
# Epoch 21/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2789 - accuracy: 0.8812
# Epoch 22/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2771 - accuracy: 0.8795
# Epoch 23/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2789 - accuracy: 0.8791
# Epoch 24/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2768 - accuracy: 0.8793
# Epoch 25/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2727 - accuracy: 0.8842
# Epoch 26/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2795 - accuracy: 0.8774
# Epoch 27/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8840
# Epoch 28/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8768
# Epoch 29/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2659 - accuracy: 0.8871
# Epoch 30/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2673 - accuracy: 0.8812
# Epoch 31/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2645 - accuracy: 0.8846
# Epoch 32/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2590 - accuracy: 0.8871
# Epoch 33/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2639 - accuracy: 0.8875
# Epoch 34/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2617 - accuracy: 0.8869
# Epoch 35/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2601 - accuracy: 0.8877
# Epoch 36/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2559 - accuracy: 0.8901
# Epoch 37/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2647 - accuracy: 0.8814
# Epoch 38/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2542 - accuracy: 0.8903
# Epoch 39/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2558 - accuracy: 0.8890
# Epoch 40/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2492 - accuracy: 0.8928
# Epoch 41/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2574 - accuracy: 0.8867
# Epoch 42/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2556 - accuracy: 0.8882
# Epoch 43/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2485 - accuracy: 0.8938
# Epoch 44/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8894
# Epoch 45/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8917
# Epoch 46/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2458 - accuracy: 0.8926
# Epoch 47/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8917
# Epoch 48/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2527 - accuracy: 0.8899
# Epoch 49/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2477 - accuracy: 0.8913
# Epoch 50/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2438 - accuracy: 0.8930
# Epoch 51/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2442 - accuracy: 0.8945
# Epoch 52/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2438 - accuracy: 0.8961
# Epoch 53/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2469 - accuracy: 0.8917
# Epoch 54/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2449 - accuracy: 0.8957
# Epoch 55/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2425 - accuracy: 0.8940
# Epoch 56/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2404 - accuracy: 0.8961
# Epoch 57/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2474 - accuracy: 0.8890
# Epoch 58/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2494 - accuracy: 0.8915
# Epoch 59/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2453 - accuracy: 0.8940
# Epoch 60/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2411 - accuracy: 0.8985
# Epoch 61/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2316 - accuracy: 0.8997
# Epoch 62/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2398 - accuracy: 0.8930
# Epoch 63/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2321 - accuracy: 0.8962
# Epoch 64/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2324 - accuracy: 0.8968
# Epoch 65/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8972
# Epoch 66/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2391 - accuracy: 0.8970
# Epoch 67/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2315 - accuracy: 0.9020
# Epoch 68/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2395 - accuracy: 0.8926
# Epoch 69/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2369 - accuracy: 0.8932
# Epoch 70/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2310 - accuracy: 0.8991
# Epoch 71/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2377 - accuracy: 0.8970
# Epoch 72/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2313 - accuracy: 0.8972
# Epoch 73/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2288 - accuracy: 0.9022
# Epoch 74/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2294 - accuracy: 0.8983
# Epoch 75/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2338 - accuracy: 0.8949
# Epoch 76/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2315 - accuracy: 0.8995
# Epoch 77/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2355 - accuracy: 0.8947
# Epoch 78/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 1s - loss: 0.2323 - accuracy: 0.8993
# Epoch 79/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 1s - loss: 0.2328 - accuracy: 0.8983
# Epoch 80/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 1s - loss: 0.2269 - accuracy: 0.9014
# Epoch 81/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 1s - loss: 0.2365 - accuracy: 0.8955
# Epoch 82/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2300 - accuracy: 0.9014
# Epoch 83/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2274 - accuracy: 0.8983
# Epoch 84/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2243 - accuracy: 0.9043
# Epoch 85/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2248 - accuracy: 0.9022
# Epoch 86/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2256 - accuracy: 0.8989
# Epoch 87/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2242 - accuracy: 0.9023
# Epoch 88/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2234 - accuracy: 0.9031
# Epoch 89/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2238 - accuracy: 0.9039
# Epoch 90/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2303 - accuracy: 0.9016
# Epoch 91/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2227 - accuracy: 0.9020
# Epoch 92/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2239 - accuracy: 0.9014
# Epoch 93/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 1s - loss: 0.2204 - accuracy: 0.9050
# Epoch 94/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2237 - accuracy: 0.9010
# Epoch 95/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2208 - accuracy: 0.9088
# Epoch 96/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2206 - accuracy: 0.9064
# Epoch 97/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2227 - accuracy: 0.9008
# Epoch 98/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2173 - accuracy: 0.9050
# Epoch 99/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2164 - accuracy: 0.9073
# Epoch 100/100
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 164/164 - 0s - loss: 0.2169 - accuracy: 0.9086

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2918 - accuracy: 0.8850
# Normal Neural Network - Loss: 0.291769415140152, Accuracy: 0.8850114345550537

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# WARNING:tensorflow:From <ipython-input-16-4db8b0f5c0b2>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['CANDIDATE' 'False_Positive' 'False_Positive' 'CANDIDATE'
#  'False_Positive']
# Actual Labels: ['CANDIDATE', 'False_Positive', 'False_Positive', 'CANDIDATE', 'False_Positive']

# %% [markdown]
# # Save the Model

# %%
# save fitted model to file
import joblib
filename = 'deep_learning.sav'
joblib.dump(model, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2c018891d0d1> in <module>
#       2 import joblib
#       3 filename = 'deep_learning.sav'
# ----> 4 joblib.dump(model, filename)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_appends(self, items)
#     803                 write(MARK)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#     807             elif n:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_appends(self, items)
#     806                 write(APPENDS)
#     807             elif n:
# --> 808                 save(tmp[0])
#     809                 write(APPEND)
#     810             # else tmp is empty, and we're done
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_appends(self, items)
#     806                 write(APPENDS)
#     807             elif n:
# --> 808                 save(tmp[0])
#     809                 write(APPEND)
#     810             # else tmp is empty, and we're done
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in _batch_setitems(self, items)
#     845                 for k, v in tmp:
#     846                     save(k)
# --> 847                     save(v)
#     848                 write(SETITEMS)
#     849             elif n:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\Anaconda3\envs\PythonData\lib\pickle.py in save(self, obj, save_persistent_id)
#     494             reduce = getattr(obj, "__reduce_ex__", None)
#     495             if reduce is not None:
# --> 496                 rv = reduce(self.proto)
#     497             else:
#     498                 reduce = getattr(obj, "__reduce__", None)
#
# TypeError: can't pickle _thread.RLock objects
